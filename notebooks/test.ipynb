# %% [markdown]
# # DC1 – Quick Smoke Test
#
# This notebook verifies that the `dc1` package is importable and that the
# key evaluation components are accessible. It is **not** a full evaluation —
# see [evaluation_quickstart.ipynb](evaluation_quickstart.ipynb) for a complete
# workflow.

# %% [markdown]
# ## Import check

# %%
import warnings
warnings.filterwarnings("ignore", message="Engine 'argo' loading failed", category=RuntimeWarning)

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

import dc1
import dc1.evaluate
from dc1.evaluation.dc1 import DC1Evaluation

print(f"dc1 imported successfully")
print(f"DC1Evaluation: {DC1Evaluation}")
